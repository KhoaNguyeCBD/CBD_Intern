# %% [markdown]
# <title> Analytical Report </title>

# %% [markdown]
# # INTRODUCTION

# %% [markdown]
# # DESCRIBING THE DATA

# %% [markdown]
# # VISUALIZATION

# %% [markdown]
# # ANALYSIS

# %%
import pandas as pd
import pandas_profiling as pdp
#data = pd.read_excel("https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset")
data = pd.read_csv("ibm-hr-analytics-attrition-dataset\WA_Fn-UseC_-HR-Employee-Attrition.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %% [markdown]
# # 1. What are key factors that are playing into current attrition rates?

# %%
data.shape
# tinh tong cua male tren tung attrition
#data.groupby('Attrition')['Life Sciences'].count()
data[['Attrition','Gender']].head()
data['Attrition'].value_counts()
data.groupby('Gender')['Attrition'].count()

Male = data[data['Gender'] == 'Male'] 
Male['Attrition'].value_counts()
pdp.ProfileReport(data)
# Out:
# C:\Users\Annie Nguyen\Anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %%
data['Attrition'].value_counts()
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
Female = data[data['Gender'] == 'Female']
Female['Attrition'].value_counts()
# Out:
# No     501
# Yes     87
# Name: Attrition, dtype: int64

# %% [markdown]
# # 2. What are key factors that are playing into current satisfaction rates?

# %% [markdown]
# # 3. When are employees leaving?

# %% [markdown]
# # CONCLUSION

# %%
import pandas as pd
import pandas_profiling as pdp
#data = pd.read_excel("https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset")
train = pd.read_csv("train.csv")
train[train['Sex'] == 'female']['Survived'].mean()
train.groupby(['Sex'])['Survived'].mean()
# Out:
# Sex
# female    0.742038
# male      0.188908
# Name: Survived, dtype: float64

# %%
pdp.ProfileReport(train)
# Out:
# C:\Users\Annie Nguyen\Anaconda3\lib\site-packages\pandas_profiling\describe.py:392: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
# ...

# %% [markdown]
# # Question 1

# %%
import pandas as pd
import pandas_profiling as pdp
import scipy.stats as sci
import numpy as np
#data = pd.read_excel("https://www.kaggle.com/pavansubhasht/ibm-hr-analytics-attrition-dataset")
data = pd.read_csv("ibm-hr-analytics-attrition-dataset\WA_Fn-UseC_-HR-Employee-Attrition.csv")

# %%
data.groupby('Attrition')['Age'].mean()
m = data['Age'].mean()
m
# Out:
# 36.923809523809524

# %%
c =data[['Attrition','Age']]
# get all age rated Yes in Attrition
ageArray = c[c['Attrition'] == 'Yes']['Age']
sci.stats.ttest_1samp(a,m)
# Out:
# Ttest_1sampResult(statistic=-5.268926728565501, pvalue=3.091919341321694e-07)

# %%
def singleTtest(x, mean):
    alpha = 0.05
    array = np.array(x)
    meanSample = array.mean()
    N = array.shape[0]
    df = N - 1
    SD = np.sqrt(sum(( array - meanSample)**2)/df)
    SE = SD / np.sqrt(N)
    tStats = (meanSample - mean)/(SE)
    cv = sci.t.ppf(1 - alpha/2, df) # 2 tailed /2
    print("mean = ",meanSample)
    print("df = ",df)
    print("SD = ",SD)
    print("SE = ",SE)
    print("tStats = ",tStats)
    print("cv = ",cv)
#x = [6,6,12,7,8]
#m = 4.6

singleTtest(a,m)
# Out:
# mean =  33.607594936708864
# df =  236
# SD =  9.689349895351622
# SE =  0.6293909097505177
# tStats =  -5.268926728565502
# cv =  1.970066853101121

# %%
DailyRateArray = data[data['Attrition'] == 'Yes']['DailyRate']
asd = np.array(DailyRateArray)
singleTtest(asd,data['DailyRate'].mean())
data['DailyRate'].mean()
# Out:
# mean =  750.3628691983122
# df =  236
# SD =  401.89951940778354
# SE =  26.106179143113835
# tStats =  -1.9965711872911438
# cv =  1.970066853101121
# 802.4857142857143

# %%
sci.stats.ttest_1samp(asd,data['DailyRate'].mean())
# Out:
# Ttest_1sampResult(statistic=-1.9965711872911438, pvalue=0.04702063396224887)

# %%
DistanceFromHomeArray = data[data['Attrition'] == 'Yes']['DistanceFromHome']
singleTtest(DistanceFromHomeArray,data['DistanceFromHome'].mean())
# Out:
# mean =  10.632911392405063
# df =  236
# SD =  8.452525269825024
# SE =  0.5490505169822184
# tStats =  2.62342779225357
# cv =  1.970066853101121

# %%
DistanceFromHomeArray = data[data['Attrition'] == 'Yes']['DistanceFromHome']
sci.stats.ttest_1samp(DistanceFromHomeArray,data['DistanceFromHome'].mean())
# Out:
# Ttest_1sampResult(statistic=2.6234277922535685, pvalue=0.009272331622219679)

# %%
EducationArray = data[data['Attrition'] == 'Yes']['Education']
meanEducation = data['Education'].mean()
singleTtest(EducationArray,meanEducation)
sci.stats.ttest_1samp(EducationArray,meanEducation)
# Out:
# mean =  2.839662447257384
# df =  236
# SD =  1.0082439277172608
# SE =  0.065492480896044
# tStats =  -1.1186432672619737
# cv =  1.970066853101121
# Ttest_1sampResult(statistic=-1.1186432672619724, pvalue=0.2644296867320878)

# %%
JobInvolvementArray = data[data['Attrition'] == 'Yes']['JobInvolvement']
meanJobInvolvement = data['JobInvolvement'].mean()
singleTtest(JobInvolvementArray,meanJobInvolvement)
sci.stats.ttest_1samp(JobInvolvementArray,meanJobInvolvement)
# Out:
# mean =  2.518987341772152
# df =  236
# SD =  0.7734047468056179
# SE =  0.05023803686054129
# tStats =  -4.1989027477832614
# cv =  1.970066853101121
# 3.802496127785573e-05

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
Numeric = data.select_dtypes(include='int64')
Numeric.iloc[0,1]
Numeric.columns[1]
Numeric['Attrition'] = data['Attrition'].copy()
NumericLength = Numeric.shape[1] - 1
result = []
for i in range(NumericLength):
    arrayTmp = Numeric[ Numeric['Attrition'] == 'Yes'][Numeric.columns[i]]
    meanTmp = Numeric.iloc[:,i].mean()
    result.append( Numeric.columns[i])
    result.append("statistic = " +str(sci.stats.ttest_1samp(arrayTmp,meanTmp)[0]) + " pvalue =" + str(sci.stats.ttest_1samp(arrayTmp,meanTmp)[1]))
print(*result, sep="\n")
# Out:
# Age
# statistic = -5.268926728565501 pvalue =3.091919341321694e-07
# DailyRate
# statistic = -1.9965711872911438 pvalue =0.04702063396224887
# DistanceFromHome
# statistic = 2.6234277922535685 pvalue =0.009272331622219679
# Education
# statistic = -1.1186432672619724 pvalue =0.2644296867320878
# EmployeeCount
# statistic = nan pvalue =nan
# EmployeeNumber
# statistic = -0.38488469433178446 pvalue =0.7006694746068023
# EnvironmentSatisfaction
# statistic = -3.3905366280447264 pvalue =0.0008175913692967167
# HourlyRate
# statistic = -0.24303683324362974 pvalue =0.8081879675889055
# JobInvolvement
# statistic = -4.198902747783257 pvalue =3.802496127785573e-05
# JobLevel
# statistic = -6.985723547253417 pvalue =2.867488751396247e-11
# JobSatisfaction
# statistic = -3.582989304028057 pvalue =0.000412552190534359
# MonthlyIncome
# statistic = -7.256448049585389 pvalue =5.693274853957249e-12
# MonthlyRate
# statistic = 0.525831199664992 pvalue =0.599499238147553
# NumCompaniesWorked
# ...

# %%
objectData=data.select_dtypes(include = 'object')
objectData
# Out:
#      Attrition     BusinessTravel              Department EducationField  \
# 0          Yes      Travel_Rarely                   Sales  Life Sciences
# 1           No  Travel_Frequently  Research & Development  Life Sciences
# 2          Yes      Travel_Rarely  Research & Development          Other
# 3           No  Travel_Frequently  Research & Development  Life Sciences
# 4           No      Travel_Rarely  Research & Development        Medical
# ...        ...                ...                     ...            ...
# 1465        No  Travel_Frequently  Research & Development        Medical
# 1466        No      Travel_Rarely  Research & Development        Medical
# 1467        No      Travel_Rarely  Research & Development  Life Sciences
# 1468        No  Travel_Frequently                   Sales        Medical
# 1469        No      Travel_Rarely  Research & Development        Medical
#
#       Gender                    JobRole MaritalStatus Over18 OverTime
# ...

# %%
for i in range(objectData.shape[1]):
    if (len(objectData.iloc[:,i].unique().tolist()) == 2):
        print(objectData.columns[i])

#objectData[ (objectData['Attrition'] == 'Yes') & (objectData['Gender'] == 'Female') ]['Gender']
objectData.loc[:,'Attrition'] = np.where(objectData['Attrition'] == 'Yes', 1,0)
# Out:
# Attrition
# Gender
# OverTime

# %%
objectData[objectData['Gender'] == 'Male']['Attrition']
'''
for i in range(objectData.shape[1]):
    if((len(objectData.iloc[:,i].unique().tolist()) == 2) and (objectData.columns[i] ~= 'Attrition') ):
        sci.ttest_ind(objectData[objectData['Gender'] == 'Male']['Attrition'],
             objectData[objectData['Gender'] == 'Female']['Attrition'])
'''
sci.ttest_ind(objectData[objectData['Gender'] == 'Male']['Attrition'],
             objectData[objectData['Gender'] == 'Female']['Attrition'])
# Out:
# Ttest_indResult(statistic=1.1289761152328313, pvalue=0.25909236414147996)

# %%
objectData.loc[:,'OverTime'] = np.where(objectData['OverTime'] == 'Yes',1,0)

# %%
sci.ttest_ind(objectData[objectData['Attrition'] == 1]['OverTime'],
             objectData[objectData['Attrition'] == 0]['OverTime'])
# Out:
# Ttest_indResult(statistic=9.729155002966676, pvalue=1.0092540336563068e-21)

# %%
sci.ttest_ind(objectData[objectData['OverTime'] == 'Yes']['Attrition'],
             objectData[objectData['OverTime'] == 'No']['Attrition'])
# Out:
# Ttest_indResult(statistic=9.729155002966676, pvalue=1.0092540336563068e-21)

# %%
def IndTtest(seriesX,seriesY):
    X = np.array(seriesX)
    Y = np.array(seriesY)
    alpha = 0.05
    meanX = X.mean()
    meanY = Y.mean()
    NX = X.shape[0]
    NY = Y.shape[0]
    dfX = NX - 1
    dfY = NY - 1
    dfTotal = dfX + dfY
    varX = sum((X - meanX)**2)/dfX
    varY = sum((Y - meanY)**2)/dfY
    Varpooled = (dfX/dfTotal)*varX + (dfY/dfTotal)*varY
    SEdiff = np.sqrt((Varpooled/NX) + (Varpooled/NY))
    tStats = (meanX - meanY)/(SEdiff)
    CV = sci.t.pdf(1 -alpha/2, dfTotal)
    pvalue =  (1 - sci.t.cdf(abs(tStats), dfTotal)) * 2
    ######################################################
    print("meanX = ",meanX)
    print("meanY = ",meanY)
    print("varX = ",varX)
    print("varY = ",varY)
    print("tStats = ",tStats)
    print("pvalue = ", pvalue)
    
    
IndTtest(data[data["Attrition"]=='Yes']['MonthlyIncome'],data[data["Attrition"]=='No']['MonthlyIncome'])
# Out:
# meanX =  4787.0928270042195
# meanY =  6832.739659367397
# varX =  13251131.516770355
# varY =  23215128.338823628
# tStats =  -6.203935765608933
# pvalue =  7.147362701687143e-10

# %%
IndTtest(objectData[objectData['Gender'] == 'Male']['Attrition'],
             objectData[objectData['Gender'] == 'Female']['Attrition'])
# Out:
# meanX =  0.17006802721088435
# meanY =  0.14795918367346939
# varX =  0.1413051031990557
# varY =  0.12628202899558563
# tStats =  1.1289761152328275
# pvalue =  0.2590923641414813

# %%
IndTtest(objectData[objectData['Attrition'] == 1]['OverTime'],
             objectData[objectData['Attrition'] == 0]['OverTime'])
# Out:
# meanX =  0.5358649789029536
# meanY =  0.23438767234387672
# varX =  0.24976757491239274
# varY =  0.17959574893881552
# tStats =  9.729155002966662
# pvalue =  0.0

# %% [markdown]
# # Question 2

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
# Age                         1470 non-null int64
# Attrition                   1470 non-null object
# BusinessTravel              1470 non-null object
# DailyRate                   1470 non-null int64
# Department                  1470 non-null object
# DistanceFromHome            1470 non-null int64
# Education                   1470 non-null int64
# EducationField              1470 non-null object
# EmployeeCount               1470 non-null int64
# EmployeeNumber              1470 non-null int64
# EnvironmentSatisfaction     1470 non-null int64
# Gender                      1470 non-null object
# HourlyRate                  1470 non-null int64
# JobInvolvement              1470 non-null int64
# JobLevel                    1470 non-null int64
# JobRole                     1470 non-null object
# JobSatisfaction             1470 non-null int64
# ...

# %%
data['JobSatisfaction'].unique()
# Out:
# array([4, 2, 3, 1], dtype=int64)

# %%
len(data['MonthlyIncome'].unique().tolist())
# Out:
# 1349

# %%
dataObject2 = data.select_dtypes(include="object")
for i in range(dataObject2.shape[1]):
     if(len(dataObject2.iloc[:,i].unique().tolist()) == 2 ):
        print(dataObject2.columns[i])
# Out:
# Attrition
# Gender
# OverTime

# %%
sci.ttest_ind(data[data['Attrition'] == 'Yes']['JobSatisfaction'],
             data[data['Attrition'] == 'No']['JobSatisfaction'])
# Out:
# Ttest_indResult(statistic=-3.9862267630568273, pvalue=7.043066741731151e-05)

# %%
sci.ttest_ind(data[data['OverTime'] == 'Yes']['JobSatisfaction'],
             data[data['OverTime'] == 'No']['JobSatisfaction'])
# Out:
# Ttest_indResult(statistic=0.9405008765145539, pvalue=0.3471154294975499)

# %%
sci.ttest_ind(data[data['Gender'] == 'Male']['JobSatisfaction'],
             data[data['Gender'] == 'Female']['JobSatisfaction'])
# Out:
# Ttest_indResult(statistic=1.2747266777649473, pvalue=0.20260772654833753)
